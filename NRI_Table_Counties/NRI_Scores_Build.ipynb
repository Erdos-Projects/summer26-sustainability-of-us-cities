# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("NRI_Table_Counties/NRI_Table_Counties.csv",dtype={'STCOFIPS': str})
features_to_keep = [
    'STCOFIPS', 'POPULATION', # Geographic & Demographic info
    'RISK_SCORE', 'RESL_SCORE', 'SOVI_SCORE', 'EAL_SCORE',                  # The Big 4 Composites
    'CFLD_RISKS', 'DRGT_RISKS', 'HWAV_RISKS', 'WFIR_RISKS',                 # Climate Risks
    'HRCN_RISKS', 'IFLD_RISKS', 'WNTW_RISKS'
]

# Filter your dataframe
df_resilience = df[features_to_keep]

df_resilience.dtypes
df_resilience.head()
# Out:
#   STCOFIPS  POPULATION  RISK_SCORE  RESL_SCORE  SOVI_SCORE  EAL_SCORE  \
# 0    01001       58764   57.569975   55.120865   38.040712  59.870050
# 1    01003      231365   96.723919   93.002545   44.243003  96.627475
# 2    01005       25160   48.123410   11.164122   96.374046  30.538366
# 3    01007       22239   39.122137   22.169211   75.254453  31.002475
# 4    01009       58992   68.479644   15.648855   69.338422  62.345297
#
#    CFLD_RISKS  DRGT_RISKS  HWAV_RISKS  WFIR_RISKS  HRCN_RISKS  IFLD_RISKS  \
# 0         NaN   45.642494   85.902376   45.737913   72.090113   65.521628
# 1        85.8   74.522901   92.196532   90.776081   99.249061   92.207379
# 2         NaN   70.038168   69.460501   48.854962   79.974969   50.763359
# 3         NaN   33.874046   59.698137   48.664122   50.062578   48.918575
# 4         NaN   55.184478   69.492614   65.044529   62.995411   69.465649
#
#    WNTW_RISKS
# 0    9.038829
# 1   59.325271
# 2   11.807766
# 3    6.938256
# 4   20.878421

# %%
df_resilience.to_csv('NRI_SCORES.csv',index=False)
