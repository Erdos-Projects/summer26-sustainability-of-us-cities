# %%
import numpy as np
import pandas as pd

# %%
finsab = pd.read_csv("data/identifiers/State,_County_and_City_FIPS_Reference_Table_20260616.csv",usecols=["State Name","County Name","StCnty FIPS Code","StCntyCity FIPS Code"])
